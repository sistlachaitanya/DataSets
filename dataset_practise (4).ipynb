# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("C:\Users\sssvc\Downloads\YESBANK.csv")
# Out:
#   Cell In[14], line 1
#     data = pd.read_csv("C:\Users\sssvc\Downloads\YESBANK.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
cls

# %%
data = pd.read_csv("C:\Users\sssvc\Downloads\YESBANK.csv")
# Out:
#   Cell In[16], line 1
#     data = pd.read_csv("C:\Users\sssvc\Downloads\YESBANK.csv")
#                        ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape

# %%
data = pd.read_csv("C:\\Users\\sssvc\\Downloads\\YESBANK.csv")

# %%
data.tail(10)
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 13  2019-05-31  156.000000  157.000000  147.199997  147.949997  143.995529
# 14  2019-06-03  147.949997  149.899994  144.600006  149.350006  147.350006
# 15  2019-06-04  148.750000  153.800003  148.600006  152.750000  152.750000
# 16  2019-06-06  149.750000  151.250000  142.300003  143.350006  143.350006
# 17  2019-06-07  143.399994  145.500000  136.250000  139.949997  139.949997
# 18  2019-06-10  142.000000  145.000000  132.500000  135.899994  135.899994
# 19  2019-06-11  135.000000  143.550003  133.550003  139.300003  139.300003
# 20  2019-06-12  136.399994  137.550003  133.800003  134.649994  134.649994
# 21  2019-06-13  130.800003  130.800003  116.099998  117.199997  117.199997
# 22  2019-06-14  118.199997  121.000000  113.000000  115.800003  115.800003
#
#       Volume
# 13   5290357
# 14   3188614
# 15   3264001
# 16   5978756
# 17   5543739
# 18   6081287
# 19   5783013
# 20   4471405
# ...

# %%
data.head(10)
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2019-05-14  155.000000  158.649994  151.500000  156.149994  151.976349
# 1  2019-05-15  154.899994  154.899994  142.500000  143.649994  139.810455
# 2  2019-05-16  143.899994  146.000000  135.000000  137.800003  134.116821
# 3  2019-05-17  141.000000  145.949997  133.050003  134.550003  130.953690
# 4  2019-05-20  142.050003  144.899994  137.199997  143.600006  139.761810
# 5  2019-05-21  144.949997  145.000000  138.600006  141.000000  137.231293
# 6  2019-05-22  140.899994  141.550003  135.449997  137.699997  134.019501
# 7  2019-05-23  143.399994  150.750000  138.750000  139.800003  136.063370
# 8  2019-05-24  140.550003  142.850006  139.500000  141.300003  137.523270
# 9  2019-05-27  141.800003  148.600006  141.000000  146.649994  142.730270
#
#     Volume
# 0  4234736
# 1  8203362
# 2  6454069
# 3  9077790
# 4  6123297
# 5  4234819
# 6  5214954
# 7  9528256
# 8  3408304
# 9  5087134

# %%
data["Open"].value_counts()

# %%
data["Close"].value_counts()
# Out:
# Close
# 156.149994    1
# 154.550003    1
# 117.199997    1
# 134.649994    1
# 139.300003    1
# 135.899994    1
# 139.949997    1
# 143.350006    1
# 152.750000    1
# 149.350006    1
# 147.949997    1
# 151.699997    1
# 143.649994    1
# 152.600006    1
# 146.649994    1
# 141.300003    1
# 139.800003    1
# 137.699997    1
# 141.000000    1
# 143.600006    1
# 134.550003    1
# 137.800003    1
# 115.800003    1
# Name: count, dtype: int64

# %%
open_price = data["Open"].value_counts()
close_price = data["Close"].value_counts()

# %%
print(f"Opening Prices of YesBank Stock are: {open_price}")
# Out:
# Opening Prices of YesBank Stock are: Open
# 148.750000    2
# 143.399994    2
# 153.949997    1
# 130.800003    1
# 136.399994    1
# 135.000000    1
# 142.000000    1
# 149.750000    1
# 147.949997    1
# 156.000000    1
# 150.350006    1
# 155.000000    1
# 154.899994    1
# 141.800003    1
# 140.550003    1
# 140.899994    1
# 144.949997    1
# 142.050003    1
# 141.000000    1
# 143.899994    1
# 118.199997    1
# Name: count, dtype: int64

# %%
print(f"Closing Prices of YesBank Stock are: {close_price}")
# Out:
# Closing Prices of YesBank Stock are: Close
# 156.149994    1
# 154.550003    1
# 117.199997    1
# 134.649994    1
# 139.300003    1
# 135.899994    1
# 139.949997    1
# 143.350006    1
# 152.750000    1
# 149.350006    1
# 147.949997    1
# 151.699997    1
# 143.649994    1
# 152.600006    1
# 146.649994    1
# 141.300003    1
# 139.800003    1
# 137.699997    1
# 141.000000    1
# 143.600006    1
# 134.550003    1
# 137.800003    1
# 115.800003    1
# Name: count, dtype: int64

# %%
adjclose_volume_data = pd.DataFrame()

# %%
adjclose_volume_data["Adj Close"] = data["Adj Close"]
adjclose_volume_data["Volume"] = data["Volume"]

# %%
adjclose_volume_data.describe()
# Out:
#         Adj Close        Volume
# count   23.000000  2.300000e+01
# mean   139.174697  6.088089e+06
# std      9.418604  2.591849e+06
# min    115.800003  3.188614e+06
# 25%    135.274994  4.353112e+06
# 50%    139.761810  5.543739e+06
# 75%    145.672768  6.423174e+06
# max    152.750000  1.428510e+07

# %%
import seaborn as sns
from matplotlib import pyplot as plt

# %%
sns.boxplot(data = data, x="High", y = "Low")
# Out:
# <Axes: xlabel='High', ylabel='Low'>

# %%
sns.boxplot(data = data, x="High", y = "Open")
# Out:
# <Axes: xlabel='High', ylabel='Open'>

# %%
sns.boxplot(data = data, x="Close", y = "Adj Close")
# Out:
# <Axes: xlabel='Close', ylabel='Adj Close'>

# %%
sns.catplot(data = data, x = "Date", y = "Open")

# %%
sns.catplot(data = data, y = "Date", x = "Open")

# %%
sns.boxplot(data = data, x="Close", y = "Date")
# Out:
# <Axes: xlabel='Close', ylabel='Date'>

# %%
sns.barplot(data=data, x="Volume", y="Date")
# Out:
# <Axes: xlabel='Volume', ylabel='Date'>

# %%
sns.barplot(data=data, y="Volume", x="Date")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 sns.barplot(data=data, y="Volume", x="Date")
#
# NameError: name 'sns' is not defined

# %%
 sns.distplot(data["Volume"])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 sns.distplot(data["Volume"])
#
# NameError: name 'sns' is not defined

# %%
data_corr = data.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 data_corr = data.corr()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
#    1995     result = np.asarray(result, dtype=dtype)
#
# ...

# %%
data_corr
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 data_corr
#
# NameError: name 'data_corr' is not defined

# %%
data = data.drop("Date", axis=1)

# %%
data
# Out:
#           Open        High         Low       Close   Adj Close    Volume
# 0   155.000000  158.649994  151.500000  156.149994  151.976349   4234736
# 1   154.899994  154.899994  142.500000  143.649994  139.810455   8203362
# 2   143.899994  146.000000  135.000000  137.800003  134.116821   6454069
# 3   141.000000  145.949997  133.050003  134.550003  130.953690   9077790
# 4   142.050003  144.899994  137.199997  143.600006  139.761810   6123297
# 5   144.949997  145.000000  138.600006  141.000000  137.231293   4234819
# 6   140.899994  141.550003  135.449997  137.699997  134.019501   5214954
# 7   143.399994  150.750000  138.750000  139.800003  136.063370   9528256
# 8   140.550003  142.850006  139.500000  141.300003  137.523270   3408304
# 9   141.800003  148.600006  141.000000  146.649994  142.730270   5087134
# 10  148.750000  154.899994  148.100006  152.600006  148.521240   6392279
# 11  153.949997  156.000000  150.699997  151.699997  147.645294   3546219
# ...

# %%
data_corr = data.corr()

# %%
data_corr
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.959332  0.914941  0.866131   0.836639 -0.493284
# High       0.959332  1.000000  0.948430  0.925175   0.899248 -0.492408
# Low        0.914941  0.948430  1.000000  0.984692   0.964528 -0.700969
# Close      0.866131  0.925175  0.984692  1.000000   0.985124 -0.722892
# Adj Close  0.836639  0.899248  0.964528  0.985124   1.000000 -0.745387
# Volume    -0.493284 -0.492408 -0.700969 -0.722892  -0.745387  1.000000

# %%
sns.heatmap(data_corr, annot=True)
# Out:
# <Axes: >

# %%
sns.catplot(data=data, x="Volume", y="Date")

# %%
sns.distplot(data["Adj Close"])
# Out:
# C:\Users\sssvc\AppData\Local\Temp\ipykernel_16772\4075338892.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data["Adj Close"])
# <Axes: xlabel='Adj Close', ylabel='Density'>

# %%
data["Volume"].value_counts().plot.pie(autopct="%1.1f%%")
plt.show()

# %%
sns.scatterplot(data=data, x="Open", y="Date", hue="Volume")
plt.show()

# %%
sns.catplot(data=data, x="Volume", y="Date", hue="Open")
plt.show()

# %%
column = "Close"

mean_val = data[column].mean()
median_val = data[column].median()
mode_val = data[column].mode()[0]

plt.figure(figsize=(10, 6))
sns.distplot(data[column], bins=20, kde=True, color='skyblue')

plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='green', linestyle='-', label=f'Median: {median_val:.2f}')
plt.axvline(mode_val, color='purple', linestyle=':', label=f'Mode: {mode_val:.2f}')

plt.legend()
# Out:
# C:\Users\sssvc\AppData\Local\Temp\ipykernel_16772\4175584234.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column], bins=20, kde=True, color='skyblue')

# %%
column = "Open"

mean_val = data[column].mean()
median_val = data[column].median()
mode_val = data[column].mode()[0]

plt.figure(figsize=(10, 6))
sns.distplot(data[column], bins=20, kde=True, color='skyblue')

plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='green', linestyle='-', label=f'Median: {median_val:.2f}')
plt.axvline(mode_val, color='purple', linestyle=':', label=f'Mode: {mode_val:.2f}')

plt.legend()
# Out:
# C:\Users\sssvc\AppData\Local\Temp\ipykernel_16772\3484831442.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column], bins=20, kde=True, color='skyblue')

# %%
column = "Adj Close"

mean_val = data[column].mean()
median_val = data[column].median()
mode_val = data[column].mode()[0]

plt.figure(figsize=(10, 6))
sns.distplot(data[column], bins=20, kde=True, color='skyblue')

plt.axvline(mean_val, color='red', linestyle='--', label=f'Mean: {mean_val:.2f}')
plt.axvline(median_val, color='green', linestyle='-', label=f'Median: {median_val:.2f}')
plt.axvline(mode_val, color='purple', linestyle=':', label=f'Mode: {mode_val:.2f}')

plt.legend()
# Out:
# C:\Users\sssvc\AppData\Local\Temp\ipykernel_16772\4043234743.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[column], bins=20, kde=True, color='skyblue')

# %%
sns.pairplot(data, hue="Close", diag_kind="kde")
plt.show()

# %%
sns.violinplot(x="Close", y="Date", data=data)
plt.show()

# %%
sns.pairplot(data, hue="Close", diag_kind="kde")
plt.show()

# %%
data.plot(kind="scatter", x="Open", y="Date", c="Purchased", colormap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:496, in to_rgba_array(c, alpha)
#     495 if isinstance(c, str):
# --> 496     raise ValueError(f"{c!r} is not a valid color value.")
#     498 if len(c) == 0:
#
# ValueError: 'Purchased' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[35], line 1
# ...

# %%
data.plot(kind="scatter", x="Open", y="Close", c="Purchased", colormap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:496, in to_rgba_array(c, alpha)
#     495 if isinstance(c, str):
# --> 496     raise ValueError(f"{c!r} is not a valid color value.")
#     498 if len(c) == 0:
#
# ValueError: 'Purchased' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[37], line 1
# ...

# %%
data.plot(kind="scatter", x="Open", y="Adj Close", c="Purchased", colormap='viridis')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_axes.py:4618, in Axes._parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4617 try:  # Is 'c' acceptable as PathCollection facecolors?
# -> 4618     colors = mcolors.to_rgba_array(c)
#    4619 except (TypeError, ValueError) as err:
#
# File ~\anaconda3\Lib\site-packages\matplotlib\colors.py:496, in to_rgba_array(c, alpha)
#     495 if isinstance(c, str):
# --> 496     raise ValueError(f"{c!r} is not a valid color value.")
#     498 if len(c) == 0:
#
# ValueError: 'Purchased' is not a valid color value.
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 1
# ...
